# %%
from pandas import Series, DataFrame
import pandas as pd

df=pd.read_pickle('chembl_bioactivities_of_P14061.pkl').head().transpose()
df
# Out:
#                                                                           0  \
# activity_comment                                                Unspecified
# assay_chemblid                                                 CHEMBL856124
# assay_description         Inhibitory activity at 10 uM against 17-beta-h...
# assay_type                                                                B
# bioactivity_type                                                 Inhibition
# ingredient_cmpd_chemblid                                       CHEMBL364060
# name_in_reference                                                        71
# operator                                                                  =
# organism                                                       Homo sapiens
# parent_cmpd_chemblid                                           CHEMBL364060
# reference                                  J. Med. Chem., (2005) 48:18:5749
# ...
