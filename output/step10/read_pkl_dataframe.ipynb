# %%
from pandas import Series, DataFrame
import pandas as pd

df=pd.read_pickle('chembl_bioact_ki_ic50_kd_summary_of_P14061.pkl')
df
# Out:
#      ingredient_cmpd_chemblid bioactivity_type operator   value units
# 1                CHEMBL364060             IC50        =     780    nM
# 12               CHEMBL583734             IC50        =     130    nM
# 13               CHEMBL576495             IC50        >    5000    nM
# 14               CHEMBL576896             IC50        =      17    nM
# 26              CHEMBL1275626             IC50        =     594    nM
# 27              CHEMBL1277340             IC50        =      30    nM
# 28              CHEMBL1277340             IC50        =      33    nM
# 29              CHEMBL1277429             IC50        =      21    nM
# 30              CHEMBL1277802             IC50        =      86    nM
# 33              CHEMBL1277708             IC50        =       8    nM
# 34              CHEMBL1277708             IC50        =      27    nM
# 35              CHEMBL1277708             IC50        =       8    nM
# ...
