# %%
import pandas as pd
import matplotlib
import seaborn as sns

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
step11 = "../output/step11/"
fda = "number_of_approved_drugs.pkl"
ligands = "number_of_bioact_records_with_unique_ligands.pkl"
bio = "number_of_bioact_records.pkl"
ic50 = "number_of_ki_ic50_kd_bioact_records.pkl"

# %%
dataframe_fda=pd.read_pickle(step11+fda)

# %%
fda_sort = dataframe_fda.sort(['Number of Approved Drugs'], ascending=False)
#fda_sort.plot(kind ='bar')

# %%
fda_sort.head(10)
# Out:
#      Number of Approved Drugs Uniprot ACC
# 12                         19      P10275
# 70                         13      Q72547
# 106                         8      Q07343
# 107                         8      Q08499
# 22                          7      P00918
# 23                          5      P22748
# 14                          5      P11511
# 56                          5      P14324
# 137                         4      P04818
# 108                         4      O76074

# %%
fda_sort.head(20).plot(kind ='bar', x = 'Uniprot ACC')

# %%
dataframe_lig=pd.read_pickle(step11+ligands)

# %%
lig_sort = dataframe_lig.sort(['Number of Bioact. records w/ Unique Ligands(Ingr.cmpd)'], ascending=False)
#lig_sort.plot(kind ='bar')

# %%
lig_sort.head()
# Out:
#      Number of Bioact. records w/ Unique Ligands(Ingr.cmpd) Uniprot ACC
# 81                                               62123           P08659
# 82                                               51455           O75164
# 115                                              35844           Q13526
# 31                                               29531           P25779
# 47                                               16485           P28482

# %%
lig_sort.head(20).plot(kind ='bar', x = 'Uniprot ACC')

# %%
dataframe_bio=pd.read_pickle(step11+bio)

# %%
bio_sort = dataframe_bio.sort(['Number of Bioactivity Records'], ascending=False)
#bio_sort.plot(kind ='bar')

# %%
bio_sort.head(20).plot(kind ='bar', x = 'Uniprot ACC')

# %%
dataframe_ic50=pd.read_pickle(step11+ic50)

# %%
ic50_sort = dataframe_ic50.sort(['Number of Ki/IC50/Kd Bioactivity Records'], ascending=False)
ic50_sort.head(20).plot(kind ='bar', x = 'Uniprot ACC')

# %%
pieces = [dataframe_fda, dataframe_lig, dataframe_bio, dataframe_ic50]
dataframe = pd.concat(pieces)
#grouped = dataframe.groupby(['Uniprot ACC'])
#duplicates = dataframe.duplicated(['Uniprot ACC'])

# %%
bioactivities_filename = "../output/step10/chembl_bioact_ki_ic50_kd_summary_of_P15056.pkl"
df = pd.read_pickle(bioactivities_filename)
# Convert to numeric data.
df = df.convert_objects(convert_numeric=True)
print df.dtypes
df['value'] *= 1e-9
# Plot bioactivities
fig, ax = plt.subplots()
nbins=50
print df['value'].min()
print df['value'].max()
bins = np.logspace(np.log10(df['value'].min()), np.log10(df['value'].max()), nbins, endpoint=True)
#print bins
df['value'].plot(kind='hist', bins=bins, logx=True)
xlabel('Kd equivalent (M)');
ylabel('compounds');
# Out:
# ingredient_cmpd_chemblid     object
# bioactivity_type             object
# operator                     object
# value                       float64
# units                        object
# dtype: object
# 2e-11
# 0.0001

# %%
bioactivities_filename = "../output/step10/chembl_bioact_ki_ic50_kd_summary_of_P15056.pkl"
df = pd.read_pickle(bioactivities_filename)
# Convert to numeric data.
df = df.convert_objects(convert_numeric=True)
# Show types
print df.dtypes
# Convert to M
df['value'] *= 1e-9
# Convert to log10(Kd / M)
df['value'] = np.log10(df['value'])
# Sort by log10(Kd / M).
df = df.sort(columns='value', ascending=True)
# Out:
# ingredient_cmpd_chemblid     object
# bioactivity_type             object
# operator                     object
# value                       float64
# units                        object
# dtype: object

# %%
df.describe()
print df.head()
print df.tail()
# Out:
#      ingredient_cmpd_chemblid bioactivity_type operator      value units
# 750              CHEMBL500659             IC50        = -10.698970    nM
# 1321             CHEMBL526479             IC50        = -10.522879    nM
# 1322             CHEMBL526479             IC50        = -10.522879    nM
# 1719             CHEMBL498344             IC50        = -10.397940    nM
# 1618             CHEMBL527029             IC50        = -10.301030    nM
#      ingredient_cmpd_chemblid bioactivity_type operator  value units
# 282              CHEMBL200130             IC50        >     -4    nM
# 1626                CHEMBL941             IC50        >     -4    nM
# 992              CHEMBL461621             IC50        >     -4    nM
# 120              CHEMBL509283             IC50        >     -4    nM
# 1064            CHEMBL1213923             IC50        >     -4    nM

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(11, 6))
sns.violinplot(df['value'], color="Set3", bw=.2, cut=.6, lw=.5, inner="points", inner_kws={"ms": 6})

# %%
filename = '../output/step11/number_of_ki_ic50_kd_bioact_records.pkl'
df = pd.read_pickle(filename)
# Convert to numeric data.
df = df.convert_objects(convert_numeric=True)
df_bio_list = list()
for uniprot_id in df['Uniprot ACC']:
    #print uniprot_id
    bioactivities_filename = "../output/step10/chembl_bioact_ki_ic50_kd_summary_of_%s.pkl" % uniprot_id
    df_bio = pd.read_pickle(bioactivities_filename)
    # Convert to numeric data.
    df_bio = df_bio.convert_objects(convert_numeric=True)
    # Convert to M
#    df_bio['units'=='pM', 'value'] *= 1e-12
#    df_bio['units'=='nM', 'value'] *= 1e-9
#    df_bio['units'=='uM', 'value'] *= 1e-6
#    df_bio['units'=='mM', 'value'] *= 1e-3
#    # Convert to log10(Kd / M)
#    df_bio['value'] = np.log10(df_bio['value'])
#    # Sort by log10(Kd / M).
#    df_bio = df_bio.sort(columns='value', ascending=True)
    # Add column.
    df_bio['Uniprot ACC'] = uniprot_id
    # Append.
    df_bio_list.append(df_bio)
    
# Concatenate.
df = pd.concat(df_bio_list, ignore_index=True)

# Convert to M
df[df['units']=='pM']['value'] *= 1e-12
df[df['units']=='nM']['value'] *= 1e-9
df[df['units']=='uM']['value'] *= 1e-6
df[df['units']=='mM']['value'] *= 1e-3
df['value'] = np.log10(df['value'])

# Drop nans
df = df[np.isfinite(df['value'])]

print df.columns
# Out:
# Index([u'ingredient_cmpd_chemblid', u'bioactivity_type', u'operator', u'value', u'units', u'Uniprot ACC'], dtype='object')

# %%
df.head()
# Out:
#   ingredient_cmpd_chemblid bioactivity_type operator      value units  \
# 0            CHEMBL1098145             IC50        = -10.522879    nM
# 1            CHEMBL1098131             IC50        = -10.522879    nM
# 2            CHEMBL1096870             IC50        = -10.522879    nM
# 3            CHEMBL1096451             IC50        = -10.522879    nM
# 4            CHEMBL1098130             IC50        = -10.522879    nM
#
#   Uniprot ACC
# 0      P28845
# 1      P28845
# 2      P28845
# 3      P28845
# 4      P28845

# %%
df.value
# Out:
# 0    -10.522879
# 1    -10.522879
# 2    -10.522879
# 3    -10.522879
# 4    -10.522879
# 5    -10.000000
# 6     -9.958607
# 7     -9.698970
# 8     -9.552842
# 9     -9.494850
# 10    -9.494850
# 11    -9.494850
# 12    -9.494850
# 13    -9.494850
# 14    -9.481486
# ...
# 178512   -4.000000
# 178513   -4.000000
# 178514   -4.000000
# 178515   -4.000000
# 178516   -4.000000
# 178517   -4.000000
# 178518   -4.000000
# 178519   -3.958607
# 178520   -3.754241
# 178521   -2.229148
# 178522   -2.000000
# 178523   -2.000000
# 178524   -2.000000
# 178525   -2.000000
# 178526   -1.000000
# Name: value, Length: 178527, dtype: float64

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(figsize=(14, 25))

#sns.violinplot(df['value'], groupby=df['Uniprot ACC'], color="Set3", bw=.2, cut=.6, lw=.5, inner="points", inner_kws={"ms": 6})
sns.violinplot(df['value'], groupby=df['Uniprot ACC'], color="Set3", bw=.2, cut=.6, lw=.5, inner="points", inner_kws={"ms": 6}, vert=False)
xlabel('log$_{10}$ K$_d$ / M');

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-cadf13b57dea> in <module>()
# ----> 1 df['units'=='nM']
#
# /Users/choderaj/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /Users/choderaj/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /Users/choderaj/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1066         res = cache.get(item)
#    1067         if res is None:
# -> 1068             values = self._data.get(item)
#    1069             res = self._box_item_values(item, values)
#    1070             cache[item] = res
#
# /Users/choderaj/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2847
#    2848             if not isnull(item):
# -> 2849                 loc = self.items.get_loc(item)
#    2850             else:
#    2851                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/choderaj/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1400         loc : int if unique index, possibly slice or mask if not
#    1401         """
# -> 1402         return self._engine.get_loc(_values_from_object(key))
#    1403
#    1404     def get_value(self, series, key):
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3807)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3687)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12310)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12261)()
#
# KeyError: False

# %%
# Out:
#    Number of Ki/IC50/Kd Bioactivity Records Uniprot ACC
# 0                                      2873      P28845
# 1                                       437      P14061
# 2                                       546      P42330
# 3                                       215      Q04828
# 4                                        40      P0A953

# %%
df[df['units']=='nM']['value']
# Out:
# 0    -1.522879
# 1    -1.522879
# 2    -1.522879
# 3    -1.522879
# 4    -1.522879
# 5    -1.000000
# 6    -0.958607
# 7    -0.698970
# 8    -0.552842
# 9    -0.494850
# 10   -0.494850
# 11   -0.494850
# 12   -0.494850
# 13   -0.494850
# 14   -0.481486
# ...
# 178512    5.000000
# 178513    5.000000
# 178514    5.000000
# 178515    5.000000
# 178516    5.000000
# 178517    5.000000
# 178518    5.000000
# 178519    5.041393
# 178520    5.245759
# 178521    6.770852
# 178522    7.000000
# 178523    7.000000
# 178524    7.000000
# 178525    7.000000
# 178526    8.000000
# Name: value, Length: 178523, dtype: float64
