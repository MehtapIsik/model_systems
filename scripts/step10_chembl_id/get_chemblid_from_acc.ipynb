# %%
from bioservices import *
s = ChEMBL(verbose=False)

print(s._target_chemblId_example)
# Out:
# CHEMBL2477

# %%
resjson = s.get_target_by_uniprotId(s._target_uniprotId_example)
resjson
# Out:
# {u'bioactivityCount': 254,
#  u'chemblId': u'CHEMBL1940',
#  u'compoundCount': 186,
#  u'description': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'geneNames': u'Unspecified',
#  u'organism': u'Homo sapiens',
#  u'preferredName': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'proteinAccession': u'Q13936',
#  u'synonyms': u'CCHL1A1,CACNL1A1,Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle,Voltage-gated calcium channel subunit alpha Cav1.2,CACNA1C,CACN2,CACH2 ,Voltage-dependent L-type calcium channel subunit alpha-1C',
#  u'targetType': u'SINGLE PROTEIN'}

# %%
trial = s.get_target_by_uniprotId('Q13936')
trial
# Out:
# {u'bioactivityCount': 254,
#  u'chemblId': u'CHEMBL1940',
#  u'compoundCount': 186,
#  u'description': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'geneNames': u'Unspecified',
#  u'organism': u'Homo sapiens',
#  u'preferredName': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'proteinAccession': u'Q13936',
#  u'synonyms': u'CCHL1A1,CACNL1A1,Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle,Voltage-gated calcium channel subunit alpha Cav1.2,CACNA1C,CACN2,CACH2 ,Voltage-dependent L-type calcium channel subunit alpha-1C',
#  u'targetType': u'SINGLE PROTEIN'}

# %%
trial["chemblId"]
# Out:
# u'CHEMBL1940'

# %%
trial_xml=s.get_target_by_uniprotId('Q13936', frmt='xml')
trial_xml
# Out:
# u"<?xml version='1.0' encoding='utf-8'?>\n<target><targetType>SINGLE PROTEIN</targetType><chemblId>CHEMBL1940</chemblId><geneNames>Unspecified</geneNames><description>Voltage-gated L-type calcium channel alpha-1C subunit</description><compoundCount>186</compoundCount><bioactivityCount>254</bioactivityCount><proteinAccession>Q13936</proteinAccession><synonyms>CCHL1A1,CACNL1A1,Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle,Voltage-gated calcium channel subunit alpha Cav1.2,CACNA1C,CACN2,CACH2 ,Voltage-dependent L-type calcium channel subunit alpha-1C</synonyms><organism>Homo sapiens</organism><preferredName>Voltage-gated L-type calcium channel alpha-1C subunit</preferredName></target>"

# %%
bioact = s.get_target_bioactivities('CHEMBL1940')
bioact
# Out:
# [{u'activity_comment': u'Unspecified',
#   u'assay_chemblid': u'CHEMBL664887',
#   u'assay_description': u'Inhibition of [3H]nitrendipine binding to L-type calcium channel dihydropyridine site of porcine cardiac sarcolemma membrane vesicles',
#   u'assay_type': u'B',
#   u'bioactivity_type': u'Ki',
#   u'ingredient_cmpd_chemblid': u'CHEMBL159854',
#   u'name_in_reference': u'3',
#   u'operator': u'=',
#   u'organism': u'Homo sapiens',
#   u'parent_cmpd_chemblid': u'CHEMBL159854',
#   u'reference': u'J. Med. Chem., (1987) 30:4:690',
#   u'target_chemblid': u'CHEMBL1940',
#   u'target_confidence': 6,
#   u'target_name': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#   u'units': u'nM',
#   u'value': u'1'},
#  {u'activity_comment': u'Unspecified',
#   u'assay_chemblid': u'CHEMBL1039575',
#   u'assay_description': u'Inhibition of Cav1.2 expressed in CHO cells by patch-clamp technique',
#   u'assay_type': u'B',
#   u'bioactivity_type': u'IC50',
# ...

# %%
bioact2 = s.get_target_bioactivities('CHEMBL1940', frmt="xml")
bioact2
# Out:
# u"<?xml version='1.0' encoding='utf-8'?>\n<list><bioactivity><target__confidence>6</target__confidence><name__in__reference>3</name__in__reference><activity__comment>Unspecified</activity__comment><reference>J. Med. Chem., (1987) 30:4:690</reference><ingredient__cmpd__chemblid>CHEMBL159854</ingredient__cmpd__chemblid><assay__type>B</assay__type><bioactivity__type>Ki</bioactivity__type><assay__chemblid>CHEMBL664887</assay__chemblid><target__name>Voltage-gated L-type calcium channel alpha-1C subunit</target__name><units>nM</units><target__chemblid>CHEMBL1940</target__chemblid><parent__cmpd__chemblid>CHEMBL159854</parent__cmpd__chemblid><value>1</value><operator>=</operator><organism>Homo sapiens</organism><assay__description>Inhibition of [3H]nitrendipine binding to L-type calcium channel dihydropyridine site of porcine cardiac sarcolemma membrane vesicles</assay__description></bioactivity><bioactivity><target__confidence>8</target__confidence><name__in__reference>4g, KVI-020, WYE-1600
# ...

# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
import json
# Convert Python nested dictionary/list to JSON (output as string)
db_json = json.dumps(trial)
db_json
# Out:
# '{"targetType": "SINGLE PROTEIN", "chemblId": "CHEMBL1940", "geneNames": "Unspecified", "description": "Voltage-gated L-type calcium channel alpha-1C subunit", "compoundCount": 186, "bioactivityCount": 254, "proteinAccession": "Q13936", "synonyms": "CCHL1A1,CACNL1A1,Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle,Voltage-gated calcium channel subunit alpha Cav1.2,CACNA1C,CACN2,CACH2 ,Voltage-dependent L-type calcium channel subunit alpha-1C", "organism": "Homo sapiens", "preferredName": "Voltage-gated L-type calcium channel alpha-1C subunit"}'

# %%
#  Convert JSON string into Python nested dictionary/list.
db_dict= json.loads(db_json)
db_dict
# Out:
# {u'bioactivityCount': 254,
#  u'chemblId': u'CHEMBL1940',
#  u'compoundCount': 186,
#  u'description': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'geneNames': u'Unspecified',
#  u'organism': u'Homo sapiens',
#  u'preferredName': u'Voltage-gated L-type calcium channel alpha-1C subunit',
#  u'proteinAccession': u'Q13936',
#  u'synonyms': u'CCHL1A1,CACNL1A1,Calcium channel, L type, alpha-1 polypeptide, isoform 1, cardiac muscle,Voltage-gated calcium channel subunit alpha Cav1.2,CACNA1C,CACN2,CACH2 ,Voltage-dependent L-type calcium channel subunit alpha-1C',
#  u'targetType': u'SINGLE PROTEIN'}

# %%
df = DataFrame(db_json["chemblId"], columns=["id"])
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-9ae6432c870f> in <module>()
# ----> 1 df = DataFrame(db_json["chemblId"], columns=["id"])
#       2 df
#
# TypeError: string indices must be integers, not str

# %%
df = Series(db_dict)
df

# %%
df=DataFrame(list(bioact))
df
# Out:
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 1        Unspecified  CHEMBL1039575
# 2        Unspecified  CHEMBL1647979
# 3        Unspecified  CHEMBL1647981
# 4        Unspecified  CHEMBL1647979
# 5        Unspecified  CHEMBL1001517
# 6        Unspecified  CHEMBL1051709
# 7        Unspecified  CHEMBL1051709
# 8        Unspecified  CHEMBL1051709
# 9        Unspecified  CHEMBL1051709
# 10       Unspecified  CHEMBL1051709
# 11       Unspecified  CHEMBL1001517
# 12       Unspecified   CHEMBL655369
# 13       Unspecified   CHEMBL655370
# 14       Unspecified   CHEMBL659152
# 15       Unspecified   CHEMBL659153
# 16       Unspecified   CHEMBL653730
# 17       Unspecified   CHEMBL653731
# 18       Unspecified   CHEMBL660545
# 19       Unspecified   CHEMBL660547
# 20       Unspecified   CHEMBL655369
# 21       Unspecified   CHEMBL659151
# 22       Unspecified   CHEMBL659152
# 23       Unspecified   CHEMBL659155
# 24       Unspecified   CHEMBL653732
# ...

# %%
df[6:8]
# Out:
#   activity_comment assay_chemblid              assay_description assay_type  \
# 6      Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 7      Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
#
#   bioactivity_type ingredient_cmpd_chemblid name_in_reference operator  \
# 6             IC50             CHEMBL561259                1h        >
# 7             IC50             CHEMBL559101                1e        >
#
#        organism parent_cmpd_chemblid                         reference  \
# 6  Homo sapiens         CHEMBL561259  J. Med. Chem., (2009) 52:16:5009
# 7  Homo sapiens         CHEMBL559101  J. Med. Chem., (2009) 52:16:5009
#
#   target_chemblid  target_confidence  \
# 6      CHEMBL1940                  8
# 7      CHEMBL1940                  8
#
#                                          target_name units  value
# 6  Voltage-gated L-type calcium channel alpha-1C ...    nM  30000
# ...

# %%
#to select rows with certain values
df.loc[df['assay_chemblid']=='CHEMBL1051709']
# Out:
#     activity_comment assay_chemblid              assay_description assay_type  \
# 6        Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 7        Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 8        Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 9        Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 10       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 52       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 53       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 56       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 57       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 58       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# 64       Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
# ...

# %%
df.loc[df['ingredient_cmpd_chemblid']=='CHEMBL561259']
# Out:
#   activity_comment assay_chemblid              assay_description assay_type  \
# 6      Unspecified  CHEMBL1051709  Inhibition of Cav 1.2 channel          B
#
#   bioactivity_type ingredient_cmpd_chemblid name_in_reference operator  \
# 6             IC50             CHEMBL561259                1h        >
#
#        organism parent_cmpd_chemblid                         reference  \
# 6  Homo sapiens         CHEMBL561259  J. Med. Chem., (2009) 52:16:5009
#
#   target_chemblid  target_confidence  \
# 6      CHEMBL1940                  8
#
#                                          target_name units  value
# 6  Voltage-gated L-type calcium channel alpha-1C ...    nM  30000

# %%
len(df['ingredient_cmpd_chemblid'])
# Out:
# 254

# %%
len(df['ingredient_cmpd_chemblid'].unique())
# Out:
# 186

# %%
df['ingredient_cmpd_chemblid'].unique()
# Out:
# array([u'CHEMBL159854', u'CHEMBL569185', u'CHEMBL1643725',
#        u'CHEMBL1643735', u'CHEMBL522211', u'CHEMBL561259', u'CHEMBL559101',
#        u'CHEMBL562926', u'CHEMBL557032', u'CHEMBL551517', u'CHEMBL495993',
#        u'CHEMBL151193', u'CHEMBL177144', u'CHEMBL151777', u'CHEMBL104082',
#        u'CHEMBL248195', u'CHEMBL247828', u'CHEMBL23451', u'CHEMBL315548',
#        u'CHEMBL39684', u'CHEMBL24491', u'CHEMBL63997', u'CHEMBL399232',
#        u'CHEMBL245598', u'CHEMBL172829', u'CHEMBL280926', u'CHEMBL317651',
#        u'CHEMBL290092', u'CHEMBL315382', u'CHEMBL530733', u'CHEMBL345843',
#        u'CHEMBL23692', u'CHEMBL39925', u'CHEMBL445837', u'CHEMBL282279',
#        u'CHEMBL559531', u'CHEMBL564757', u'CHEMBL107213', u'CHEMBL482637',
#        u'CHEMBL552196', u'CHEMBL561379', u'CHEMBL552402', u'CHEMBL1643718',
#        u'CHEMBL1643719', u'CHEMBL1643734', u'CHEMBL631', u'CHEMBL36673',
#        u'CHEMBL552382', u'CHEMBL550652', u'CHEMBL539426', u'CHEMBL347573',
# ...

# %%
df_ki=df.loc[df['bioactivity_type']=="Ki"]
print len(df_ki)
df_ki
# Out:
# 28
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 24       Unspecified   CHEMBL653732
# 42       Unspecified   CHEMBL653732
# 47       Unspecified   CHEMBL684132
# 54       Unspecified   CHEMBL653732
# 67       Unspecified   CHEMBL653732
# 83       Unspecified   CHEMBL653732
# 108      Unspecified   CHEMBL659866
# 120      Unspecified   CHEMBL659866
# 122      Unspecified   CHEMBL659866
# 127      Unspecified   CHEMBL653732
# 134      Unspecified   CHEMBL653732
# 137      Unspecified   CHEMBL659866
# 140      Unspecified   CHEMBL664887
# 143      Unspecified   CHEMBL659866
# 153      Unspecified   CHEMBL659866
# 159      Unspecified   CHEMBL653732
# 164      Unspecified   CHEMBL664887
# 171      Unspecified   CHEMBL664887
# 191      Unspecified   CHEMBL664887
# 192      Unspecified   CHEMBL664887
# 193      Unspecified   CHEMBL664887
# 194      Unspecified   CHEMBL664887
# 197      Unspecified   CHEMBL653733
# 199      Unspecified   CHEMBL664887
# ...

# %%
df_ic50=df.loc[df['bioactivity_type']=="Ki"]
print len(df_ic50)
df_ic50
# Out:
# 28
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 24       Unspecified   CHEMBL653732
# 42       Unspecified   CHEMBL653732
# 47       Unspecified   CHEMBL684132
# 54       Unspecified   CHEMBL653732
# 67       Unspecified   CHEMBL653732
# 83       Unspecified   CHEMBL653732
# 108      Unspecified   CHEMBL659866
# 120      Unspecified   CHEMBL659866
# 122      Unspecified   CHEMBL659866
# 127      Unspecified   CHEMBL653732
# 134      Unspecified   CHEMBL653732
# 137      Unspecified   CHEMBL659866
# 140      Unspecified   CHEMBL664887
# 143      Unspecified   CHEMBL659866
# 153      Unspecified   CHEMBL659866
# 159      Unspecified   CHEMBL653732
# 164      Unspecified   CHEMBL664887
# 171      Unspecified   CHEMBL664887
# 191      Unspecified   CHEMBL664887
# 192      Unspecified   CHEMBL664887
# 193      Unspecified   CHEMBL664887
# 194      Unspecified   CHEMBL664887
# 197      Unspecified   CHEMBL653733
# 199      Unspecified   CHEMBL664887
# ...

# %%
df_ic50_ki=df[(df.bioactivity_type=="Ki")|((df.bioactivity_type=="IC50"))]
print len(df_ic50_ki)
df_ic50_ki
# Out:
# 105
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 1        Unspecified  CHEMBL1039575
# 5        Unspecified  CHEMBL1001517
# 6        Unspecified  CHEMBL1051709
# 7        Unspecified  CHEMBL1051709
# 8        Unspecified  CHEMBL1051709
# 9        Unspecified  CHEMBL1051709
# 10       Unspecified  CHEMBL1051709
# 11       Unspecified  CHEMBL1001517
# 24       Unspecified   CHEMBL653732
# 26       Unspecified   CHEMBL923065
# 28       Unspecified   CHEMBL660543
# 42       Unspecified   CHEMBL653732
# 44       Unspecified   CHEMBL660543
# 47       Unspecified   CHEMBL684132
# 50        Not Active   CHEMBL660544
# 52       Unspecified  CHEMBL1051709
# 53       Unspecified  CHEMBL1051709
# 54       Unspecified   CHEMBL653732
# 55       Unspecified  CHEMBL1001517
# 56       Unspecified  CHEMBL1051709
# 57       Unspecified  CHEMBL1051709
# 58       Unspecified  CHEMBL1051709
# 64       Unspecified  CHEMBL1051709
# 65       Unspecified  CHEMBL1051709
# ...

# %% [markdown]
# # Picking the bioassays that report Ki, IC50, Kd, Kd1 or Kd2

# %%
df_ic50_ki=df[(df.bioactivity_type=="Ki")|(df.bioactivity_type=="IC50")|(df.bioactivity_type=="Kd")|(df.bioactivity_type=="Kd1")|(df.bioactivity_type=="Kd2")]
print len(df_ic50_ki)
df_ic50_ki
# Out:
# 143
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 1        Unspecified  CHEMBL1039575
# 5        Unspecified  CHEMBL1001517
# 6        Unspecified  CHEMBL1051709
# 7        Unspecified  CHEMBL1051709
# 8        Unspecified  CHEMBL1051709
# 9        Unspecified  CHEMBL1051709
# 10       Unspecified  CHEMBL1051709
# 11       Unspecified  CHEMBL1001517
# 16       Unspecified   CHEMBL653730
# 17       Unspecified   CHEMBL653731
# 24       Unspecified   CHEMBL653732
# 26       Unspecified   CHEMBL923065
# 27       Unspecified   CHEMBL666481
# 28       Unspecified   CHEMBL660543
# 29       Unspecified   CHEMBL653728
# 30       Unspecified   CHEMBL666481
# 31       Unspecified   CHEMBL653730
# 32       Unspecified   CHEMBL653731
# 37       Unspecified   CHEMBL653730
# 40       Unspecified   CHEMBL687168
# 41       Unspecified   CHEMBL666481
# 42       Unspecified   CHEMBL653732
# 43       Unspecified   CHEMBL653728
# 44       Unspecified   CHEMBL660543
# ...

# %%
df_ic50_ki[['ingredient_cmpd_chemblid','assay_type','operator','value','units']]
len(df_ic50_ki[['ingredient_cmpd_chemblid','assay_type','operator','value','units']])
# Out:
# 143

# %%
df_ic50_ki[df_ic50_ki.units!='nM'].count()
# Out:
# activity_comment            2
# assay_chemblid              2
# assay_description           2
# assay_type                  2
# bioactivity_type            2
# ingredient_cmpd_chemblid    2
# name_in_reference           2
# operator                    2
# organism                    2
# parent_cmpd_chemblid        2
# reference                   2
# target_chemblid             2
# target_confidence           2
# target_name                 2
# units                       2
# value                       2
# dtype: int64

# %%
df2=df[((df.bioactivity_type=="Ki")|(df.bioactivity_type=="IC50")|(df.bioactivity_type=="Kd")|(df.bioactivity_type=="Kd1")|(df.bioactivity_type=="Kd2"))&(df.units=='nM')]
print len(df2)
df2
# Out:
# 141
#     activity_comment assay_chemblid  \
# 0        Unspecified   CHEMBL664887
# 1        Unspecified  CHEMBL1039575
# 5        Unspecified  CHEMBL1001517
# 6        Unspecified  CHEMBL1051709
# 7        Unspecified  CHEMBL1051709
# 8        Unspecified  CHEMBL1051709
# 9        Unspecified  CHEMBL1051709
# 10       Unspecified  CHEMBL1051709
# 11       Unspecified  CHEMBL1001517
# 16       Unspecified   CHEMBL653730
# 17       Unspecified   CHEMBL653731
# 24       Unspecified   CHEMBL653732
# 26       Unspecified   CHEMBL923065
# 27       Unspecified   CHEMBL666481
# 28       Unspecified   CHEMBL660543
# 29       Unspecified   CHEMBL653728
# 30       Unspecified   CHEMBL666481
# 31       Unspecified   CHEMBL653730
# 32       Unspecified   CHEMBL653731
# 37       Unspecified   CHEMBL653730
# 40       Unspecified   CHEMBL687168
# 41       Unspecified   CHEMBL666481
# 42       Unspecified   CHEMBL653732
# 43       Unspecified   CHEMBL653728
# 44       Unspecified   CHEMBL660543
# ...

# %%
df2[['ingredient_cmpd_chemblid','bioactivity_type','operator','value','units']]
# Out:
#     ingredient_cmpd_chemblid bioactivity_type operator   value units
# 0               CHEMBL159854               Ki        =       1    nM
# 1               CHEMBL569185             IC50        >   30000    nM
# 5               CHEMBL522211             IC50        =   20000    nM
# 6               CHEMBL561259             IC50        >   30000    nM
# 7               CHEMBL559101             IC50        >   30000    nM
# 8               CHEMBL562926             IC50        =   30000    nM
# 9               CHEMBL557032             IC50        >   30000    nM
# 10              CHEMBL551517             IC50        >   30000    nM
# 11              CHEMBL495993             IC50        >   30000    nM
# 16              CHEMBL177144              Kd1        =    0.23    nM
# 17              CHEMBL177144              Kd2        =      85    nM
# 24              CHEMBL104082               Ki        =    18.2    nM
# 26              CHEMBL247828             IC50        =    3500    nM
# ...

# %% [markdown]
# # get approved drugs

# %%
get_approved_drugs(self, query, frmt="json")
